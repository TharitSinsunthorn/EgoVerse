# %%
from sqlalchemy import (
    MetaData,
    Table,
    Column,
    Integer,
    String,
    Boolean,
    Float,
    text,
)
from egomimic.utils.aws.aws_sql import (
    TableRow,
    add_episode,
    update_episode,
    create_default_engine,
    episode_hash_to_table_row,
    delete_episodes,
    episode_table_to_df,
    delete_all_episodes,
)

# %%
engine = create_default_engine()
# Out:
# Tables in schema 'app': ['episodes']

# %%
def drop_table(table_name):
    with engine.connect() as connection:
        connection.execute(text(f"DROP TABLE IF EXISTS app.{table_name} CASCADE;"))
        connection.commit()
    print(f"Dropped table '{table_name}' from schema 'app' if it existed.")


drop_table("episodes")

# %%
def create_table():
    metadata = MetaData(schema="app")

    Table(
        "episodes",
        metadata,
        Column("episode_hash", String, primary_key=True),
        Column("operator", String),
        Column("lab", String),
        Column("num_frames", Integer),
        Column("task", String),
        Column("task_description", String),
        Column("scene", String),
        Column(
            "objects", String
        ),  # Store as JSON or comma-separated list of object names
        Column("processed_path", String),
        Column("mp4_path", String),
        Column("is_deleted", Boolean),
        Column("embodiment", String),
        Column("robot_name", String),
        Column("is_eval", Boolean),
        Column("eval_score", Float),
        Column("eval_success", Boolean),
    )

    metadata.create_all(engine)
    print("Created table 'episodes' in schema 'app'.")


create_table()

# %%
# Add Episode Test
episode = TableRow(
    episode_hash=123457,
    operator="jdoe",
    lab="lab-x",
    num_frames=1500,
    task="pick_and_place",
    task_description="Dummy row for table inspection",
    scene="kitchen",
    objects="cup,plate,spoon",
    processed_path="/data/processed/abc123",
    mp4_path="/data/videos/abc123.mp4",
    embodiment="ur5",
    robot_name="robby",
    is_eval=True,
    eval_score=0.85,
    eval_success=True,
)

# %%
add_episode(engine, episode)

# %%
df = episode_table_to_df(engine)
df
# Out:
#                  episode_hash operator  lab  num_frames          task  \
# 0  2025-10-25-16-16-56-437000        s    s          -1             w
# 1  2025-10-25-17-00-15-821000        s    s          -1             w
# 2  1970-01-21-09-16-48-819000   anikeh  rl2          -1  fold clothes
# 3  1970-01-21-09-16-51-615000  aniketh  rl2          -1  fold clothes
# 4  2025-10-25-20-42-10-112000      anu  rl2          -1          fold
# 5  2025-10-25-20-46-12-384000      anu  rl2          -1          fold
#
#   task_description   scene               objects processed_path mp4_path  \
# 0                        s                   {s}
# 1                        s                   {s}
# 2                   scene1                 shirt
# 3                   scene1                 shirt
# 4       do thsutff     wal  {this,that,evertunf}
# 5       do thsutff     wal  {this,that,evertunf}
#
#    is_deleted     embodiment     robot_name  is_eval  eval_score  eval_success
# 0       False      ARIA_TEST      ARIA_TEST    False        -1.0          True
# 1       False      ARIA_TEST      ARIA_TEST    False        -1.0          True
# 2       False  ARIA_BIMANUAL  ARIA_BIMANUAL    False        -1.0          True
# 3       False  ARIA_BIMANUAL  ARIA_BIMANUAL    False        -1.0          True
# 4       False       EVE_TEST           rbot    False        -1.0          True
# 5       False       EVE_TEST           rbot    False        -1.0          True

# %%
## WARNING DO NOT RUN THIS IT WILL DELETE ALL EPISODES FROM THE TABLE

delete_all_episodes(engine)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 delete_all_episodes(engine)
#
# NameError: name 'delete_all_episodes' is not defined

# %%
episode.operator = "simar"
update_episode(engine, episode)

# %%
episode_hash_to_table_row(engine, 123456)

# %%
delete_episodes(engine, [123456, 123457])
